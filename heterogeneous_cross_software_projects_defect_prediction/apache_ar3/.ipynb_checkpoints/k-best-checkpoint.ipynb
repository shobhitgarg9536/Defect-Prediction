# %%
import pandas as pd
import numpy as np
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 27)
pd.set_option('display.width', 1000)
print('asss')
# Out:
# asss

# %%
#loading and selection of best fit columns from jdt.csv
jdt_df = pd.read_csv("pde.csv")
jdt_df['class']=jdt_df['class'].map({'clean':0,'buggy':1})
print(jdt_df.info())
jdt_df_1 = jdt_df.iloc[:,1:62]
jdt_labels = jdt_df.iloc[:,62]
#print(jdt_df_1.info())
best_features = SelectKBest(score_func=chi2, k=15)
jdt_fit = best_features.fit_transform(jdt_df_1,jdt_labels)
jdt_fit_columns = best_features.get_support(indices=True)
jdt_fit_column_names = list(jdt_df.columns)
jdt_fit_selected_columns_name = []
for jdt_fit_column in jdt_fit_columns:
    jdt_fit_selected_columns_name.append(jdt_fit_column_names[jdt_fit_column])
print(jdt_fit_selected_columns_name)
print('asss')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1497 entries, 0 to 1496
# Data columns (total 63 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   id                                   1497 non-null   int64
#  1   ck_oo_numberOfPrivateMethods         1497 non-null   int64
#  2   LDHH_lcom                            1497 non-null   float64
#  3   LDHH_fanIn                           1497 non-null   float64
#  4   numberOfNonTrivialBugsFoundUntil:    1497 non-null   int64
#  5   WCHU_numberOfPublicAttributes        1497 non-null   float64
#  6   WCHU_numberOfAttributes              1497 non-null   float64
#  7   CvsWEntropy                          1497 non-null   float64
#  8   LDHH_numberOfPublicMethods           1497 non-null   float64
#  9   WCHU_fanIn                           1497 non-null   float64
#  10  LDHH_numberOfPrivateAttributes       1497 non-null   float64
#  11  CvsEntropy                           1497 non-null   float64
#  12  LDHH_numberOfPublicAttributes        1497 non-null   float64
#  13  WCHU_numberOfPrivateMethods          1497 non-null   float64
#  14  WCHU_numberOfMethods                 1497 non-null   float64
#  15  ck_oo_numberOfPublicAttributes       1497 non-null   int64
#  16  ck_oo_noc                            1497 non-null   int64
#  17  numberOfCriticalBugsFoundUntil:      1497 non-null   int64
#  18  ck_oo_wmc                            1497 non-null   int64
#  19  LDHH_numberOfPrivateMethods          1497 non-null   float64
#  20  WCHU_numberOfPrivateAttributes       1497 non-null   float64
#  21  CvsLogEntropy                        1497 non-null   float64
#  22  WCHU_noc                             1497 non-null   float64
#  23  LDHH_numberOfAttributesInherited     1497 non-null   float64
#  24  WCHU_wmc                             1497 non-null   float64
#  25  ck_oo_fanOut                         1497 non-null   int64
#  26  ck_oo_numberOfLinesOfCode            1497 non-null   int64
#  27  ck_oo_numberOfAttributesInherited    1497 non-null   int64
#  28  ck_oo_numberOfMethods                1497 non-null   int64
#  29  ck_oo_dit                            1497 non-null   int64
#  30  ck_oo_fanIn                          1497 non-null   int64
#  31  LDHH_noc                             1497 non-null   float64
#  32  WCHU_dit                             1497 non-null   float64
#  33  ck_oo_lcom                           1497 non-null   int64
#  34  WCHU_numberOfAttributesInherited     1497 non-null   float64
#  35  ck_oo_rfc                            1497 non-null   int64
#  36  LDHH_wmc                             1497 non-null   float64
#  37  LDHH_numberOfAttributes              1497 non-null   float64
#  38  LDHH_numberOfLinesOfCode             1497 non-null   float64
#  39  WCHU_fanOut                          1497 non-null   float64
#  40  WCHU_lcom                            1497 non-null   float64
#  41  ck_oo_cbo                            1497 non-null   int64
#  42  WCHU_rfc                             1497 non-null   float64
#  43  ck_oo_numberOfAttributes             1497 non-null   int64
#  44  numberOfHighPriorityBugsFoundUntil:  1497 non-null   int64
#  45  ck_oo_numberOfPrivateAttributes      1497 non-null   int64
#  46  numberOfMajorBugsFoundUntil:         1497 non-null   int64
#  47  WCHU_numberOfPublicMethods           1497 non-null   float64
#  48  LDHH_dit                             1497 non-null   float64
#  49  WCHU_cbo                             1497 non-null   float64
#  50  CvsLinEntropy                        1497 non-null   float64
#  51  WCHU_numberOfMethodsInherited        1497 non-null   float64
#  52  numberOfBugsFoundUntil:              1497 non-null   int64
#  53  LDHH_fanOut                          1497 non-null   float64
#  54  LDHH_numberOfMethodsInherited        1497 non-null   float64
#  55  LDHH_rfc                             1497 non-null   float64
#  56  ck_oo_numberOfMethodsInherited       1497 non-null   int64
#  57  ck_oo_numberOfPublicMethods          1497 non-null   int64
#  58  LDHH_cbo                             1497 non-null   float64
#  59  WCHU_numberOfLinesOfCode             1497 non-null   float64
#  60  CvsExpEntropy                        1497 non-null   float64
#  61  LDHH_numberOfMethods                 1497 non-null   float64
#  62  class                                1497 non-null   int64
# dtypes: float64(39), int64(24)
# memory usage: 736.9 KB
# None
# ['LDHH_fanIn', 'numberOfNonTrivialBugsFoundUntil:', 'LDHH_numberOfPrivateAttributes', 'WCHU_numberOfMethods', 'numberOfCriticalBugsFoundUntil:', 'WCHU_wmc', 'ck_oo_fanOut', 'WCHU_dit', 'WCHU_numberOfAttributesInherited', 'WCHU_lcom', 'ck_oo_cbo', 'WCHU_rfc', 'WCHU_numberOfMethodsInherited', 'LDHH_rfc', 'LDHH_cbo']
# asss

# %%
#loading and selection of best fit columns from safe.csv
ar5_df = pd.read_csv("ar6.csv")
ar5_df['defects'] = ar5_df['defects'].map({False:1,True:0})
print(ar5_df.info())
ar5_df_1 = ar5_df.iloc[:,1:30]
ar5_labels = ar5_df.iloc[:,30]
#print(ar5_labels.head())
best_features = SelectKBest(score_func=chi2, k=15)
ar5_fit = best_features.fit_transform(ar5_df_1,ar5_labels)
ar5_fit_columns = best_features.get_support(indices=True)
ar5_fit_column_names = list(ar5_df_1.columns)
ar5_fit_selected_columns_name = []
for ar5_fit_column in ar5_fit_columns:
    ar5_fit_selected_columns_name.append(ar5_fit_column_names[ar5_fit_column])
print(ar5_fit_selected_columns_name)
print('dssd')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 101 entries, 0 to 100
# Data columns (total 31 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   id                                101 non-null    int64
#  1   total_loc                         101 non-null    int64
#  2   blank_loc                         101 non-null    int64
#  3   comment_loc                       101 non-null    int64
#  4   code_and_comment_loc              101 non-null    int64
#  5   executable_loc                    101 non-null    int64
#  6   unique_operands                   101 non-null    int64
#  7   unique_operators                  101 non-null    int64
#  8   total_operands                    101 non-null    int64
#  9   total_operators                   101 non-null    int64
#  10  halstead_vocabulary               101 non-null    int64
#  11  halstead_length                   101 non-null    int64
#  12  halstead_volume                   101 non-null    int64
#  13  halstead_level                    101 non-null    float64
#  14  halstead_difficulty               101 non-null    float64
#  15  halstead_effort                   101 non-null    float64
#  16  halstead_error                    101 non-null    float64
#  17  halstead_time                     101 non-null    float64
#  18  branch_count                      101 non-null    float64
#  19  decision_count                    101 non-null    int64
#  20  call_pairs                        101 non-null    int64
#  21  condition_count                   101 non-null    int64
#  22  multiple_condition_count          101 non-null    int64
#  23  cyclomatic_complexity             101 non-null    int64
#  24  cyclomatic_density                101 non-null    float64
#  25  decision_density                  101 non-null    float64
#  26  design_complexity                 101 non-null    float64
#  27  design_density                    101 non-null    float64
#  28  normalized_cyclomatic_complexity  101 non-null    float64
#  29  formal_parameters                 101 non-null    float64
#  30  defects                           101 non-null    int64
# dtypes: float64(12), int64(19)
# memory usage: 24.6 KB
# None
# ['blank_loc', 'code_and_comment_loc', 'executable_loc', 'unique_operands', 'total_operators', 'halstead_vocabulary', 'halstead_length', 'halstead_volume', 'halstead_level', 'halstead_effort', 'halstead_error', 'halstead_time', 'branch_count', 'decision_count', 'condition_count']
# dssd

# %%
#conversion of datasets
jdt_matrix = pd.DataFrame(jdt_fit)
ar5_matrix = pd.DataFrame(ar5_fit)
print(jdt_matrix.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1497 entries, 0 to 1496
# Data columns (total 15 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       1497 non-null   float64
#  1   1       1497 non-null   float64
#  2   2       1497 non-null   float64
#  3   3       1497 non-null   float64
#  4   4       1497 non-null   float64
#  5   5       1497 non-null   float64
#  6   6       1497 non-null   float64
#  7   7       1497 non-null   float64
#  8   8       1497 non-null   float64
#  9   9       1497 non-null   float64
#  10  10      1497 non-null   float64
#  11  11      1497 non-null   float64
#  12  12      1497 non-null   float64
#  13  13      1497 non-null   float64
#  14  14      1497 non-null   float64
# dtypes: float64(15)
# memory usage: 175.6 KB
# None

# %%
#Testing------------------------------------------------------------------
import seaborn as sn
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(15,15))

#corr_data_frame = pd.concat([ar5_matrix, jdt_matrix], axis=1,).corr()
corr_data_frame = pd.concat([ar5_matrix, jdt_matrix], axis=1, keys=['ar5_matrix', 'jdt_matrix']).corr().loc['ar5_matrix', 'jdt_matrix']

#print(corr_data_frame)
svm = sn.heatmap(corr_data_frame, annot=True, linewidths=.5, ax=ax)
ax.set_yticklabels(jdt_fit_selected_columns_name)
ax.set_xticklabels(ar5_fit_selected_columns_name)
plt.yticks(rotation=0) 
plt.xticks(rotation=90)
plt.show()

figure = svm.get_figure()    
figure.savefig('svm_conf.png', dpi=400)

# %%
#calculation of correlation
corr_data_frame = pd.concat([ar5_matrix, jdt_matrix], axis=1, keys=['ar5_matrix', 'jdt_matrix']).corr().loc['ar5_matrix', 'jdt_matrix']
corr_metrix = pd.DataFrame(corr_data_frame.values,columns=ar5_fit_selected_columns_name)
corr_metrix['index_name'] = jdt_fit_selected_columns_name
corr_metrix.set_index('index_name', inplace = True)
#print("matix", corr_metrix)
#file = open("matrix_jdt_zing.txt", "w")
#file.write(str(corr_metrix))
#file.close()
#print('asss')

corr_metrix.to_csv("pde_ar4.csv")

corr_pairs = corr_metrix.unstack()

#print(corr_pairs)
sorted_pairs = corr_pairs.sort_values(kind="quicksort")

print(sorted_pairs)
# Out:
#                       index_name
# halstead_effort       LDHH_numberOfPrivateAttributes      -0.154952
# halstead_volume       LDHH_cbo                            -0.140285
#                       LDHH_numberOfPrivateAttributes      -0.138543
# decision_count        LDHH_cbo                            -0.135760
#                       LDHH_numberOfPrivateAttributes      -0.127636
#                       WCHU_rfc                            -0.122661
#                       WCHU_lcom                           -0.122609
#                       ck_oo_fanOut                        -0.120327
# halstead_effort       LDHH_cbo                            -0.119345
# halstead_volume       ck_oo_fanOut                        -0.118902
#                       WCHU_dit                            -0.107957
# decision_count        numberOfCriticalBugsFoundUntil:     -0.106830
# condition_count       LDHH_numberOfPrivateAttributes      -0.106598
# decision_count        WCHU_dit                            -0.106474
# halstead_error        LDHH_numberOfPrivateAttributes      -0.098567
# halstead_volume       numberOfCriticalBugsFoundUntil:     -0.093981
# halstead_vocabulary   LDHH_numberOfPrivateAttributes      -0.093775
# condition_count       LDHH_cbo                            -0.093532
# halstead_volume       WCHU_rfc                            -0.091302
#                       WCHU_lcom                           -0.091176
# halstead_effort       ck_oo_fanOut                        -0.085736
# halstead_error        LDHH_cbo                            -0.081775
# halstead_level        LDHH_numberOfPrivateAttributes      -0.075423
# halstead_effort       WCHU_dit                            -0.072365
# halstead_length       LDHH_numberOfPrivateAttributes      -0.072161
# total_operators       LDHH_numberOfPrivateAttributes      -0.071070
# decision_count        LDHH_rfc                            -0.064062
#                       WCHU_numberOfMethods                -0.062016
# halstead_volume       WCHU_numberOfMethods                -0.058076
# halstead_effort       WCHU_rfc                            -0.056120
#                       WCHU_lcom                           -0.055770
# total_operators       LDHH_cbo                            -0.051385
# halstead_vocabulary   LDHH_cbo                            -0.049434
# halstead_error        ck_oo_fanOut                        -0.043848
# condition_count       ck_oo_fanOut                        -0.043205
# halstead_error        WCHU_dit                            -0.041791
# decision_count        WCHU_wmc                            -0.041218
# condition_count       WCHU_dit                            -0.036556
# halstead_level        LDHH_cbo                            -0.035113
# halstead_volume       LDHH_rfc                            -0.033701
# halstead_length       LDHH_cbo                            -0.030586
#                       ck_oo_fanOut                        -0.028638
# halstead_error        WCHU_rfc                            -0.027023
#                       WCHU_lcom                           -0.026651
# halstead_level        ck_oo_fanOut                        -0.021702
# halstead_length       WCHU_dit                            -0.020750
# code_and_comment_loc  numberOfNonTrivialBugsFoundUntil:   -0.020340
# unique_operands       numberOfNonTrivialBugsFoundUntil:   -0.019613
# halstead_vocabulary   ck_oo_fanOut                        -0.018922
# halstead_time         numberOfNonTrivialBugsFoundUntil:   -0.018414
# code_and_comment_loc  LDHH_fanIn                          -0.017502
# total_operators       ck_oo_fanOut                        -0.017353
# unique_operands       LDHH_fanIn                          -0.017042
# halstead_time         LDHH_fanIn                          -0.015591
# condition_count       WCHU_rfc                            -0.015387
# code_and_comment_loc  WCHU_numberOfAttributesInherited    -0.015005
# condition_count       WCHU_lcom                           -0.014979
# code_and_comment_loc  ck_oo_cbo                           -0.014791
# unique_operands       WCHU_numberOfAttributesInherited    -0.014470
#                       ck_oo_cbo                           -0.014263
# halstead_effort       numberOfCriticalBugsFoundUntil:     -0.013467
# halstead_level        WCHU_dit                            -0.013465
# halstead_time         WCHU_numberOfAttributesInherited    -0.013148
#                       ck_oo_cbo                           -0.012938
# executable_loc        LDHH_cbo                            -0.012149
# halstead_level        WCHU_rfc                            -0.010224
#                       WCHU_lcom                           -0.009944
# halstead_vocabulary   WCHU_dit                            -0.008777
#                       WCHU_rfc                            -0.007732
# total_operators       WCHU_dit                            -0.007435
# halstead_vocabulary   WCHU_lcom                           -0.007338
# total_operators       WCHU_rfc                            -0.006587
#                       WCHU_lcom                           -0.006333
# code_and_comment_loc  WCHU_numberOfMethodsInherited       -0.003311
# halstead_length       WCHU_rfc                            -0.003188
#                       WCHU_lcom                           -0.002960
# unique_operands       WCHU_numberOfMethodsInherited       -0.002807
# halstead_time         WCHU_numberOfMethodsInherited       -0.001577
# executable_loc        LDHH_numberOfPrivateAttributes       0.012699
# halstead_length       numberOfCriticalBugsFoundUntil:      0.019892
# halstead_volume       WCHU_wmc                             0.023801
# halstead_error        numberOfCriticalBugsFoundUntil:      0.034163
# total_operators       numberOfCriticalBugsFoundUntil:      0.034380
# halstead_level        numberOfCriticalBugsFoundUntil:      0.037389
# condition_count       numberOfCriticalBugsFoundUntil:      0.041554
# halstead_effort       WCHU_numberOfMethods                 0.050214
# halstead_length       WCHU_numberOfMethods                 0.053539
# halstead_error        WCHU_numberOfMethods                 0.062543
# halstead_vocabulary   numberOfCriticalBugsFoundUntil:      0.063834
# blank_loc             LDHH_cbo                             0.066813
# branch_count          LDHH_cbo                             0.066865
# decision_count        numberOfNonTrivialBugsFoundUntil:    0.071632
# condition_count       WCHU_numberOfMethods                 0.072883
# decision_count        WCHU_numberOfMethodsInherited        0.079430
# total_operators       WCHU_numberOfMethods                 0.083117
# halstead_level        WCHU_numberOfMethods                 0.085451
# decision_count        LDHH_fanIn                           0.085640
# branch_count          numberOfNonTrivialBugsFoundUntil:    0.087866
# decision_count        ck_oo_cbo                            0.090854
#                       WCHU_numberOfAttributesInherited     0.091242
# halstead_time         LDHH_cbo                             0.092094
# unique_operands       LDHH_cbo                             0.093665
# code_and_comment_loc  LDHH_cbo                             0.093817
# halstead_time         LDHH_rfc                             0.100829
# unique_operands       LDHH_rfc                             0.101137
# code_and_comment_loc  LDHH_rfc                             0.101144
# branch_count          LDHH_fanIn                           0.101598
#                       WCHU_numberOfAttributesInherited     0.101649
#                       ck_oo_cbo                            0.101856
# executable_loc        ck_oo_fanOut                         0.103817
#                       WCHU_dit                             0.110140
#                       WCHU_rfc                             0.111468
#                       WCHU_lcom                            0.111692
# branch_count          WCHU_numberOfMethodsInherited        0.111884
# halstead_length       LDHH_rfc                             0.123150
# halstead_effort       LDHH_rfc                             0.123320
# total_operators       LDHH_rfc                             0.126789
# halstead_vocabulary   WCHU_numberOfMethods                 0.130193
# blank_loc             LDHH_numberOfPrivateAttributes       0.131762
#                       numberOfNonTrivialBugsFoundUntil:    0.132907
#                       WCHU_rfc                             0.136460
#                       WCHU_lcom                            0.136586
# branch_count          LDHH_rfc                             0.138177
#                       LDHH_numberOfPrivateAttributes       0.138697
# executable_loc        numberOfCriticalBugsFoundUntil:      0.139792
# branch_count          WCHU_rfc                             0.141831
#                       WCHU_lcom                            0.141920
# blank_loc             LDHH_fanIn                           0.149620
#                       WCHU_numberOfAttributesInherited     0.149659
#                       ck_oo_cbo                            0.149893
# halstead_level        LDHH_rfc                             0.152220
# executable_loc        LDHH_rfc                             0.155210
# halstead_volume       numberOfNonTrivialBugsFoundUntil:    0.156022
# blank_loc             LDHH_rfc                             0.159408
#                       WCHU_numberOfMethodsInherited        0.159988
# code_and_comment_loc  WCHU_rfc                             0.160456
#                       WCHU_lcom                            0.160456
# unique_operands       WCHU_rfc                             0.160678
#                       WCHU_lcom                            0.160679
# halstead_time         WCHU_rfc                             0.160805
#                       WCHU_lcom                            0.160807
# executable_loc        WCHU_numberOfMethods                 0.161498
# halstead_length       WCHU_wmc                             0.166643
# halstead_volume       WCHU_numberOfMethodsInherited        0.167295
# halstead_time         LDHH_numberOfPrivateAttributes       0.168183
# unique_operands       LDHH_numberOfPrivateAttributes       0.169028
# code_and_comment_loc  LDHH_numberOfPrivateAttributes       0.169311
# halstead_error        LDHH_rfc                             0.173818
# halstead_volume       LDHH_fanIn                           0.174287
# unique_operands       WCHU_wmc                             0.179256
# halstead_volume       ck_oo_cbo                            0.179401
# code_and_comment_loc  WCHU_wmc                             0.179523
# halstead_volume       WCHU_numberOfAttributesInherited     0.179696
# halstead_time         WCHU_wmc                             0.181096
# blank_loc             ck_oo_fanOut                         0.186970
# condition_count       LDHH_rfc                             0.187603
# branch_count          ck_oo_fanOut                         0.191296
# total_operators       WCHU_wmc                             0.193015
# code_and_comment_loc  numberOfCriticalBugsFoundUntil:      0.194742
# unique_operands       numberOfCriticalBugsFoundUntil:      0.194805
# halstead_time         numberOfCriticalBugsFoundUntil:      0.195013
# branch_count          numberOfCriticalBugsFoundUntil:      0.195792
# blank_loc             numberOfCriticalBugsFoundUntil:      0.199958
#                       WCHU_dit                             0.199963
# branch_count          WCHU_dit                             0.204174
# unique_operands       ck_oo_fanOut                         0.210259
# code_and_comment_loc  ck_oo_fanOut                         0.210319
# halstead_time         ck_oo_fanOut                         0.210353
# halstead_level        WCHU_wmc                             0.214763
# halstead_vocabulary   LDHH_rfc                             0.214789
# halstead_effort       WCHU_wmc                             0.217211
# code_and_comment_loc  WCHU_dit                             0.221626
# unique_operands       WCHU_dit                             0.221785
# halstead_time         WCHU_dit                             0.221904
# branch_count          WCHU_wmc                             0.233937
# halstead_error        WCHU_wmc                             0.238458
# executable_loc        WCHU_wmc                             0.241259
# code_and_comment_loc  WCHU_numberOfMethods                 0.243215
# unique_operands       WCHU_numberOfMethods                 0.243444
# halstead_time         WCHU_numberOfMethods                 0.244519
# executable_loc        numberOfNonTrivialBugsFoundUntil:    0.251729
# branch_count          WCHU_numberOfMethods                 0.255581
# blank_loc             WCHU_wmc                             0.260425
#                       WCHU_numberOfMethods                 0.264515
# condition_count       WCHU_wmc                             0.265878
# executable_loc        WCHU_numberOfAttributesInherited     0.269907
#                       ck_oo_cbo                            0.270116
# halstead_length       numberOfNonTrivialBugsFoundUntil:    0.271627
# executable_loc        WCHU_numberOfMethodsInherited        0.274386
#                       LDHH_fanIn                           0.282274
# halstead_length       WCHU_numberOfMethodsInherited        0.296687
#                       ck_oo_cbo                            0.297336
#                       WCHU_numberOfAttributesInherited     0.297444
#                       LDHH_fanIn                           0.297562
# total_operators       numberOfNonTrivialBugsFoundUntil:    0.299745
# halstead_vocabulary   WCHU_wmc                             0.302244
# total_operators       WCHU_numberOfMethodsInherited        0.327046
#                       ck_oo_cbo                            0.328680
#                       WCHU_numberOfAttributesInherited     0.328835
#                       LDHH_fanIn                           0.332876
# halstead_level        numberOfNonTrivialBugsFoundUntil:    0.337928
#                       LDHH_fanIn                           0.361773
#                       WCHU_numberOfMethodsInherited        0.364553
#                       ck_oo_cbo                            0.365217
#                       WCHU_numberOfAttributesInherited     0.365239
# halstead_effort       numberOfNonTrivialBugsFoundUntil:    0.420315
# halstead_error        numberOfNonTrivialBugsFoundUntil:    0.441751
# halstead_effort       LDHH_fanIn                           0.448319
#                       WCHU_numberOfMethodsInherited        0.450461
#                       ck_oo_cbo                            0.458520
#                       WCHU_numberOfAttributesInherited     0.458736
# halstead_error        WCHU_numberOfMethodsInherited        0.469064
#                       WCHU_numberOfAttributesInherited     0.471877
#                       ck_oo_cbo                            0.471996
# halstead_vocabulary   numberOfNonTrivialBugsFoundUntil:    0.481070
# halstead_error        LDHH_fanIn                           0.482147
# condition_count       numberOfNonTrivialBugsFoundUntil:    0.485309
# halstead_vocabulary   LDHH_fanIn                           0.507724
#                       WCHU_numberOfMethodsInherited        0.511691
#                       WCHU_numberOfAttributesInherited     0.512482
#                       ck_oo_cbo                            0.512526
# condition_count       WCHU_numberOfMethodsInherited        0.512803
#                       WCHU_numberOfAttributesInherited     0.516239
#                       ck_oo_cbo                            0.516301
#                       LDHH_fanIn                           0.524478
# dtype: float64

# %%
strong_pairs = sorted_pairs[(sorted_pairs) > 0.05]

print(strong_pairs.sort_index(axis=0, level=None, ascending=True, inplace=False, sort_remaining=True))
# Out:
#                       index_name
# blank_loc             LDHH_cbo                             0.066813
#                       LDHH_fanIn                           0.149620
#                       LDHH_numberOfPrivateAttributes       0.131762
#                       LDHH_rfc                             0.159408
#                       WCHU_dit                             0.199963
#                       WCHU_lcom                            0.136586
#                       WCHU_numberOfAttributesInherited     0.149659
#                       WCHU_numberOfMethods                 0.264515
#                       WCHU_numberOfMethodsInherited        0.159988
#                       WCHU_rfc                             0.136460
#                       WCHU_wmc                             0.260425
#                       ck_oo_cbo                            0.149893
#                       ck_oo_fanOut                         0.186970
#                       numberOfCriticalBugsFoundUntil:      0.199958
#                       numberOfNonTrivialBugsFoundUntil:    0.132907
# branch_count          LDHH_cbo                             0.066865
#                       LDHH_fanIn                           0.101598
#                       LDHH_numberOfPrivateAttributes       0.138697
#                       LDHH_rfc                             0.138177
#                       WCHU_dit                             0.204174
#                       WCHU_lcom                            0.141920
#                       WCHU_numberOfAttributesInherited     0.101649
#                       WCHU_numberOfMethods                 0.255581
#                       WCHU_numberOfMethodsInherited        0.111884
#                       WCHU_rfc                             0.141831
#                       WCHU_wmc                             0.233937
#                       ck_oo_cbo                            0.101856
#                       ck_oo_fanOut                         0.191296
#                       numberOfCriticalBugsFoundUntil:      0.195792
#                       numberOfNonTrivialBugsFoundUntil:    0.087866
# code_and_comment_loc  LDHH_cbo                             0.093817
#                       LDHH_numberOfPrivateAttributes       0.169311
#                       LDHH_rfc                             0.101144
#                       WCHU_dit                             0.221626
#                       WCHU_lcom                            0.160456
#                       WCHU_numberOfMethods                 0.243215
#                       WCHU_rfc                             0.160456
#                       WCHU_wmc                             0.179523
#                       ck_oo_fanOut                         0.210319
#                       numberOfCriticalBugsFoundUntil:      0.194742
# condition_count       LDHH_fanIn                           0.524478
#                       LDHH_rfc                             0.187603
#                       WCHU_numberOfAttributesInherited     0.516239
#                       WCHU_numberOfMethods                 0.072883
#                       WCHU_numberOfMethodsInherited        0.512803
#                       WCHU_wmc                             0.265878
#                       ck_oo_cbo                            0.516301
#                       numberOfNonTrivialBugsFoundUntil:    0.485309
# decision_count        LDHH_fanIn                           0.085640
#                       WCHU_numberOfAttributesInherited     0.091242
#                       WCHU_numberOfMethodsInherited        0.079430
#                       ck_oo_cbo                            0.090854
#                       numberOfNonTrivialBugsFoundUntil:    0.071632
# executable_loc        LDHH_fanIn                           0.282274
#                       LDHH_rfc                             0.155210
#                       WCHU_dit                             0.110140
#                       WCHU_lcom                            0.111692
#                       WCHU_numberOfAttributesInherited     0.269907
#                       WCHU_numberOfMethods                 0.161498
#                       WCHU_numberOfMethodsInherited        0.274386
#                       WCHU_rfc                             0.111468
#                       WCHU_wmc                             0.241259
#                       ck_oo_cbo                            0.270116
#                       ck_oo_fanOut                         0.103817
#                       numberOfCriticalBugsFoundUntil:      0.139792
#                       numberOfNonTrivialBugsFoundUntil:    0.251729
# halstead_effort       LDHH_fanIn                           0.448319
#                       LDHH_rfc                             0.123320
#                       WCHU_numberOfAttributesInherited     0.458736
#                       WCHU_numberOfMethods                 0.050214
#                       WCHU_numberOfMethodsInherited        0.450461
#                       WCHU_wmc                             0.217211
#                       ck_oo_cbo                            0.458520
#                       numberOfNonTrivialBugsFoundUntil:    0.420315
# halstead_error        LDHH_fanIn                           0.482147
#                       LDHH_rfc                             0.173818
#                       WCHU_numberOfAttributesInherited     0.471877
#                       WCHU_numberOfMethods                 0.062543
#                       WCHU_numberOfMethodsInherited        0.469064
#                       WCHU_wmc                             0.238458
#                       ck_oo_cbo                            0.471996
#                       numberOfNonTrivialBugsFoundUntil:    0.441751
# halstead_length       LDHH_fanIn                           0.297562
#                       LDHH_rfc                             0.123150
#                       WCHU_numberOfAttributesInherited     0.297444
#                       WCHU_numberOfMethods                 0.053539
#                       WCHU_numberOfMethodsInherited        0.296687
#                       WCHU_wmc                             0.166643
#                       ck_oo_cbo                            0.297336
#                       numberOfNonTrivialBugsFoundUntil:    0.271627
# halstead_level        LDHH_fanIn                           0.361773
#                       LDHH_rfc                             0.152220
#                       WCHU_numberOfAttributesInherited     0.365239
#                       WCHU_numberOfMethods                 0.085451
#                       WCHU_numberOfMethodsInherited        0.364553
#                       WCHU_wmc                             0.214763
#                       ck_oo_cbo                            0.365217
#                       numberOfNonTrivialBugsFoundUntil:    0.337928
# halstead_time         LDHH_cbo                             0.092094
#                       LDHH_numberOfPrivateAttributes       0.168183
#                       LDHH_rfc                             0.100829
#                       WCHU_dit                             0.221904
#                       WCHU_lcom                            0.160807
#                       WCHU_numberOfMethods                 0.244519
#                       WCHU_rfc                             0.160805
#                       WCHU_wmc                             0.181096
#                       ck_oo_fanOut                         0.210353
#                       numberOfCriticalBugsFoundUntil:      0.195013
# halstead_vocabulary   LDHH_fanIn                           0.507724
#                       LDHH_rfc                             0.214789
#                       WCHU_numberOfAttributesInherited     0.512482
#                       WCHU_numberOfMethods                 0.130193
#                       WCHU_numberOfMethodsInherited        0.511691
#                       WCHU_wmc                             0.302244
#                       ck_oo_cbo                            0.512526
#                       numberOfCriticalBugsFoundUntil:      0.063834
#                       numberOfNonTrivialBugsFoundUntil:    0.481070
# halstead_volume       LDHH_fanIn                           0.174287
#                       WCHU_numberOfAttributesInherited     0.179696
#                       WCHU_numberOfMethodsInherited        0.167295
#                       ck_oo_cbo                            0.179401
#                       numberOfNonTrivialBugsFoundUntil:    0.156022
# total_operators       LDHH_fanIn                           0.332876
#                       LDHH_rfc                             0.126789
#                       WCHU_numberOfAttributesInherited     0.328835
#                       WCHU_numberOfMethods                 0.083117
#                       WCHU_numberOfMethodsInherited        0.327046
#                       WCHU_wmc                             0.193015
#                       ck_oo_cbo                            0.328680
#                       numberOfNonTrivialBugsFoundUntil:    0.299745
# unique_operands       LDHH_cbo                             0.093665
#                       LDHH_numberOfPrivateAttributes       0.169028
#                       LDHH_rfc                             0.101137
#                       WCHU_dit                             0.221785
#                       WCHU_lcom                            0.160679
#                       WCHU_numberOfMethods                 0.243444
#                       WCHU_rfc                             0.160678
#                       WCHU_wmc                             0.179256
#                       ck_oo_fanOut                         0.210259
#                       numberOfCriticalBugsFoundUntil:      0.194805
# dtype: float64
