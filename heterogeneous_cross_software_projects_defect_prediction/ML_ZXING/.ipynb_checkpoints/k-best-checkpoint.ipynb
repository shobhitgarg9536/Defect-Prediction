# %%
import pandas as pd
import numpy as np
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 27)
pd.set_option('display.width', 1000)
print('asss')
# Out:
# asss

# %%
#loading and selection of best fit columns from jdt.csv
jdt_df = pd.read_csv("ML.csv")
#print(jdt_df.info())
jdt_df_1 = jdt_df.iloc[:,1:62]
jdt_labels = jdt_df.iloc[:,62]
#print(jdt_labels)
best_features = SelectKBest(score_func=chi2, k=15)
jdt_fit = best_features.fit_transform(jdt_df_1,jdt_labels)
jdt_fit_columns = best_features.get_support(indices=True)
jdt_fit_column_names = list(jdt_df.columns)
jdt_fit_selected_columns_name = []
for jdt_fit_column in jdt_fit_columns:
    jdt_fit_selected_columns_name.append(jdt_fit_column_names[jdt_fit_column])
print(jdt_fit_selected_columns_name)
print('asss')
# Out:
# ['LDHH_fanIn', 'WCHU_numberOfMethods', 'numberOfCriticalBugsFoundUntil:', 'WCHU_wmc', 'ck_oo_fanOut', 'ck_oo_dit', 'WCHU_dit', 'WCHU_numberOfAttributesInherited', 'WCHU_fanOut', 'WCHU_lcom', 'ck_oo_cbo', 'WCHU_rfc', 'numberOfHighPriorityBugsFoundUntil:', 'WCHU_numberOfMethodsInherited', 'LDHH_cbo']
# asss

# %%
#loading and selection of best fit columns from safe.csv
ar5_df = pd.read_csv("zxing.csv")
#print(ar5_df.info())
ar5_df_1 = ar5_df.iloc[:,1:27]
ar5_labels = ar5_df.iloc[:,27]
#print(ar5_labels)
best_features = SelectKBest(score_func=chi2, k=15)
ar5_fit = best_features.fit_transform(ar5_df_1,ar5_labels)
ar5_fit_columns = best_features.get_support(indices=True)
ar5_fit_column_names = list(ar5_df.columns)
ar5_fit_selected_columns_name = []
for ar5_fit_column in ar5_fit_columns:
    ar5_fit_selected_columns_name.append(ar5_fit_column_names[ar5_fit_column])
print(ar5_fit_selected_columns_name)
print('dssd')
# Out:
# ['AvgLineComment', 'CountLine', 'CountLineBlank', 'CountLineCode', 'CountLineCodeDecl', 'CountLineCodeExe', 'CountLineComment', 'CountSemicolon', 'CountStmt', 'CountStmtDecl', 'CountStmtExe', 'MaxCyclomaticModified', 'RatioCommentToCode', 'SumCyclomatic', 'SumCyclomaticModified']
# dssd

# %%
#conversion of datasets
jdt_matrix = pd.DataFrame(jdt_fit)
ar5_matrix = pd.DataFrame(ar5_fit)
print(jdt_matrix.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1862 entries, 0 to 1861
# Data columns (total 15 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       1862 non-null   float64
#  1   1       1862 non-null   float64
#  2   2       1862 non-null   float64
#  3   3       1862 non-null   float64
#  4   4       1862 non-null   float64
#  5   5       1862 non-null   float64
#  6   6       1862 non-null   float64
#  7   7       1862 non-null   float64
#  8   8       1862 non-null   float64
#  9   9       1862 non-null   float64
#  10  10      1862 non-null   float64
#  11  11      1862 non-null   float64
#  12  12      1862 non-null   float64
#  13  13      1862 non-null   float64
#  14  14      1862 non-null   float64
# dtypes: float64(15)
# memory usage: 218.3 KB
# None

# %%
#Testing------------------------------------------------------------------
import seaborn as sn
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(15,15))

#corr_data_frame = pd.concat([ar5_matrix, jdt_matrix], axis=1,).corr()
corr_data_frame = pd.concat([ar5_matrix, jdt_matrix], axis=1, keys=['ar5_matrix', 'jdt_matrix']).corr().loc['ar5_matrix', 'jdt_matrix']

#print(corr_data_frame)
sn.heatmap(corr_data_frame, annot=True, linewidths=.5, ax=ax)
plt.show()

# %%
#calculation of correlation
corr_data_frame = pd.concat([ar5_matrix, jdt_matrix], axis=1, keys=['ar5_matrix', 'jdt_matrix']).corr().loc['ar5_matrix', 'jdt_matrix']
corr_metrix = pd.DataFrame(corr_data_frame.values,columns=ar5_fit_selected_columns_name)
corr_metrix['index_name'] = jdt_fit_selected_columns_name
corr_metrix.set_index('index_name', inplace = True)
#print("matix", corr_metrix)
#file = open("matrix_jdt_zing.txt", "w")
#file.write(str(corr_metrix))
#file.close()
#print('asss')

corr_pairs = corr_metrix.unstack()

#print(corr_pairs)
sorted_pairs = corr_pairs.sort_values(kind="quicksort")

print(sorted_pairs)
# Out:
#                        index_name
# RatioCommentToCode     ck_oo_fanOut                          -0.051115
#                        WCHU_lcom                             -0.049867
# CountSemicolon         ck_oo_cbo                             -0.048958
# RatioCommentToCode     WCHU_numberOfMethodsInherited         -0.048082
#                        numberOfHighPriorityBugsFoundUntil:   -0.046995
# CountLineCode          ck_oo_cbo                             -0.044752
# RatioCommentToCode     LDHH_cbo                              -0.044289
#                        WCHU_numberOfAttributesInherited      -0.043092
# CountLineBlank         ck_oo_cbo                             -0.042586
# CountLineComment       ck_oo_cbo                             -0.042382
# CountLineCodeDecl      ck_oo_cbo                             -0.041092
# CountLineCode          WCHU_rfc                              -0.038681
#                        numberOfCriticalBugsFoundUntil:       -0.037936
# CountSemicolon         WCHU_rfc                              -0.036990
# RatioCommentToCode     ck_oo_cbo                             -0.036931
# CountStmtDecl          ck_oo_cbo                             -0.036607
# RatioCommentToCode     WCHU_dit                              -0.036501
# CountStmtDecl          WCHU_rfc                              -0.036374
# CountLineCode          WCHU_wmc                              -0.035596
# CountLineComment       WCHU_rfc                              -0.035390
# CountLineBlank         WCHU_rfc                              -0.035354
# CountLineCode          ck_oo_fanOut                          -0.034409
#                        WCHU_numberOfMethodsInherited         -0.034038
# CountSemicolon         WCHU_numberOfMethodsInherited         -0.033407
# RatioCommentToCode     WCHU_numberOfMethods                  -0.031821
# CountLineBlank         WCHU_lcom                             -0.031649
# CountSemicolon         numberOfCriticalBugsFoundUntil:       -0.031159
# AvgLineComment         WCHU_rfc                              -0.030881
# CountLineCode          numberOfHighPriorityBugsFoundUntil:   -0.030364
# CountSemicolon         WCHU_lcom                             -0.030270
#                        numberOfHighPriorityBugsFoundUntil:   -0.029933
# CountLineCodeDecl      WCHU_rfc                              -0.029608
# CountLineCode          WCHU_lcom                             -0.029581
# RatioCommentToCode     numberOfCriticalBugsFoundUntil:       -0.029240
# CountLineCodeExe       WCHU_rfc                              -0.028892
# CountLineCodeDecl      WCHU_numberOfMethodsInherited         -0.028733
# CountLineCode          LDHH_cbo                              -0.028697
# RatioCommentToCode     WCHU_rfc                              -0.028553
# CountStmtDecl          WCHU_lcom                             -0.028459
# CountLineCode          LDHH_fanIn                            -0.028432
# AvgLineComment         ck_oo_cbo                             -0.028391
# CountLineBlank         WCHU_numberOfMethodsInherited         -0.028309
# CountSemicolon         ck_oo_fanOut                          -0.028064
#                        LDHH_fanIn                            -0.027778
#                        LDHH_cbo                              -0.027360
# CountLineCode          WCHU_numberOfAttributesInherited      -0.027311
# CountLineBlank         WCHU_numberOfAttributesInherited      -0.026966
# RatioCommentToCode     WCHU_fanOut                           -0.026689
# CountStmtDecl          LDHH_cbo                              -0.026452
# CountLineCodeExe       ck_oo_cbo                             -0.026255
# CountLineBlank         numberOfCriticalBugsFoundUntil:       -0.026023
# CountSemicolon         WCHU_numberOfAttributesInherited      -0.025798
# CountStmtDecl          WCHU_numberOfAttributesInherited      -0.025207
#                        WCHU_numberOfMethodsInherited         -0.025004
#                        numberOfHighPriorityBugsFoundUntil:   -0.024798
# CountLineBlank         ck_oo_fanOut                          -0.024613
#                        numberOfHighPriorityBugsFoundUntil:   -0.024609
# CountSemicolon         WCHU_wmc                              -0.024388
# CountLineCodeDecl      WCHU_numberOfMethods                  -0.024371
# CountStmtDecl          ck_oo_fanOut                          -0.024181
# CountLineBlank         WCHU_dit                              -0.023472
# CountLineComment       WCHU_lcom                             -0.023178
# CountLineBlank         LDHH_cbo                              -0.023073
# CountStmtDecl          numberOfCriticalBugsFoundUntil:       -0.023068
# CountLineCodeDecl      numberOfHighPriorityBugsFoundUntil:   -0.022438
# CountLineCode          WCHU_numberOfMethods                  -0.022344
# CountLineCodeExe       WCHU_lcom                             -0.022143
# RatioCommentToCode     LDHH_fanIn                            -0.021912
# CountStmtDecl          WCHU_dit                              -0.021425
# CountLineBlank         LDHH_fanIn                            -0.021265
# CountLineComment       WCHU_numberOfMethodsInherited         -0.021095
# CountLineCode          WCHU_fanOut                           -0.020763
# CountLineCodeExe       LDHH_cbo                              -0.020680
# CountLineCodeDecl      WCHU_fanOut                           -0.020651
# CountLineComment       LDHH_cbo                              -0.020489
# CountSemicolon         WCHU_numberOfMethods                  -0.020329
# CountLineCodeExe       WCHU_numberOfAttributesInherited      -0.019448
# CountSemicolon         WCHU_dit                              -0.019352
# CountLineCode          WCHU_dit                              -0.019321
# CountLineComment       numberOfHighPriorityBugsFoundUntil:   -0.019279
# CountLineCodeExe       WCHU_dit                              -0.018401
# CountLineCodeDecl      WCHU_numberOfAttributesInherited      -0.018339
# CountLineBlank         WCHU_wmc                              -0.018103
# CountLineCodeExe       numberOfHighPriorityBugsFoundUntil:   -0.017771
# CountLineCodeDecl      LDHH_cbo                              -0.017131
# CountStmtDecl          WCHU_fanOut                           -0.016963
# CountLineComment       ck_oo_fanOut                          -0.016841
# CountStmtDecl          LDHH_fanIn                            -0.016789
# CountLineCodeExe       WCHU_numberOfMethodsInherited         -0.016380
# CountLineCodeDecl      WCHU_lcom                             -0.016337
# CountLineBlank         WCHU_fanOut                           -0.015857
# CountSemicolon         ck_oo_dit                             -0.015671
#                        WCHU_fanOut                           -0.015188
# CountLineCodeExe       ck_oo_fanOut                          -0.014952
# CountLineCodeDecl      ck_oo_fanOut                          -0.014273
# CountStmtDecl          WCHU_wmc                              -0.013394
# CountLineCodeExe       WCHU_fanOut                           -0.012735
#                        numberOfCriticalBugsFoundUntil:       -0.012440
# CountLineCodeDecl      numberOfCriticalBugsFoundUntil:       -0.012418
# CountLineComment       WCHU_numberOfAttributesInherited      -0.012132
#                        numberOfCriticalBugsFoundUntil:       -0.010992
# CountLineCodeDecl      WCHU_dit                              -0.010736
# CountLineBlank         WCHU_numberOfMethods                  -0.010277
# CountLineComment       WCHU_dit                              -0.009692
# CountStmtDecl          WCHU_numberOfMethods                  -0.009416
# CountLineCodeExe       LDHH_fanIn                            -0.009402
# SumCyclomatic          ck_oo_cbo                             -0.008864
# CountStmtExe           ck_oo_cbo                             -0.008510
# CountLineCodeDecl      LDHH_fanIn                            -0.007877
# SumCyclomatic          WCHU_rfc                              -0.007854
# CountLineBlank         ck_oo_dit                             -0.005872
# MaxCyclomaticModified  WCHU_numberOfMethods                  -0.003891
# CountLineCodeExe       WCHU_numberOfMethods                  -0.003263
# CountLineComment       LDHH_fanIn                            -0.002959
# CountLineCodeExe       WCHU_wmc                              -0.001606
#                        ck_oo_dit                             -0.001035
# CountLineCodeDecl      WCHU_wmc                              -0.000287
# CountStmtDecl          ck_oo_dit                              0.003390
# SumCyclomaticModified  ck_oo_cbo                              0.003624
# AvgLineComment         WCHU_wmc                               0.003745
# CountStmtExe           WCHU_rfc                               0.004313
# CountLineComment       WCHU_wmc                               0.004577
# CountLineCode          ck_oo_dit                              0.005973
# CountLine              WCHU_wmc                               0.006022
# CountLineComment       ck_oo_dit                              0.006391
# RatioCommentToCode     ck_oo_dit                              0.006472
# CountLine              WCHU_numberOfMethods                   0.008151
# SumCyclomaticModified  WCHU_rfc                               0.008871
# CountLineComment       WCHU_fanOut                            0.009870
# CountLineCodeDecl      ck_oo_dit                              0.011112
# CountLine              ck_oo_dit                              0.011599
# MaxCyclomaticModified  ck_oo_cbo                              0.012333
# RatioCommentToCode     WCHU_wmc                               0.012558
# SumCyclomatic          WCHU_wmc                               0.012755
# AvgLineComment         LDHH_cbo                               0.013167
# CountLine              WCHU_fanOut                            0.017201
# AvgLineComment         ck_oo_dit                              0.017254
# MaxCyclomaticModified  WCHU_fanOut                            0.017285
# AvgLineComment         numberOfHighPriorityBugsFoundUntil:    0.020136
# CountStmtExe           WCHU_wmc                               0.021471
# CountStmt              WCHU_rfc                               0.022005
# MaxCyclomaticModified  numberOfHighPriorityBugsFoundUntil:    0.022473
# AvgLineComment         WCHU_numberOfMethodsInherited          0.022577
# MaxCyclomaticModified  LDHH_cbo                               0.022714
#                        WCHU_rfc                               0.023182
#                        ck_oo_dit                              0.023710
#                        WCHU_wmc                               0.026726
#                        WCHU_numberOfMethodsInherited          0.027889
# CountLineComment       WCHU_numberOfMethods                   0.028299
# CountStmt              ck_oo_cbo                              0.028857
# CountLine              ck_oo_cbo                              0.029347
# MaxCyclomaticModified  WCHU_numberOfAttributesInherited       0.031376
# AvgLineComment         numberOfCriticalBugsFoundUntil:        0.031596
#                        LDHH_fanIn                             0.032123
# SumCyclomaticModified  WCHU_wmc                               0.032566
# MaxCyclomaticModified  WCHU_dit                               0.033609
# CountLine              LDHH_fanIn                             0.034005
# MaxCyclomaticModified  LDHH_fanIn                             0.035938
# AvgLineComment         WCHU_numberOfMethods                   0.036646
# MaxCyclomaticModified  WCHU_lcom                              0.037437
# SumCyclomatic          WCHU_numberOfMethods                   0.037482
# CountStmtExe           ck_oo_dit                              0.037820
# MaxCyclomaticModified  numberOfCriticalBugsFoundUntil:        0.038174
# SumCyclomatic          LDHH_cbo                               0.038250
# CountLine              WCHU_rfc                               0.039285
#                        numberOfCriticalBugsFoundUntil:        0.039323
# SumCyclomatic          numberOfHighPriorityBugsFoundUntil:    0.041160
#                        ck_oo_dit                              0.041910
#                        WCHU_numberOfMethodsInherited          0.042132
# CountLine              LDHH_cbo                               0.042577
# AvgLineComment         WCHU_fanOut                            0.043038
# CountLine              numberOfHighPriorityBugsFoundUntil:    0.043285
# MaxCyclomaticModified  ck_oo_fanOut                           0.043672
# CountStmtExe           WCHU_numberOfMethodsInherited          0.044216
#                        numberOfHighPriorityBugsFoundUntil:    0.045922
#                        LDHH_cbo                               0.046914
# SumCyclomaticModified  ck_oo_dit                              0.047143
# AvgLineComment         ck_oo_fanOut                           0.047585
# CountLine              WCHU_numberOfMethodsInherited          0.049096
# AvgLineComment         WCHU_numberOfAttributesInherited       0.049857
#                        WCHU_lcom                              0.051302
# CountLine              WCHU_dit                               0.052273
# SumCyclomatic          numberOfCriticalBugsFoundUntil:        0.052740
# CountLine              WCHU_numberOfAttributesInherited       0.052919
# SumCyclomatic          LDHH_fanIn                             0.053633
# CountLine              ck_oo_fanOut                           0.057053
# CountStmtExe           WCHU_numberOfMethods                   0.057566
# AvgLineComment         WCHU_dit                               0.058467
# SumCyclomatic          WCHU_fanOut                            0.059241
# SumCyclomaticModified  WCHU_numberOfMethodsInherited          0.061417
#                        LDHH_cbo                               0.062069
# CountStmtExe           LDHH_fanIn                             0.062345
# SumCyclomaticModified  numberOfHighPriorityBugsFoundUntil:    0.062642
# CountStmtExe           numberOfCriticalBugsFoundUntil:        0.063530
# CountLine              WCHU_lcom                              0.069427
# SumCyclomaticModified  WCHU_numberOfMethods                   0.069628
# CountStmt              ck_oo_dit                              0.073147
# SumCyclomatic          ck_oo_fanOut                           0.073637
#                        WCHU_numberOfAttributesInherited       0.075081
# CountStmtExe           WCHU_fanOut                            0.075198
# CountStmt              WCHU_wmc                               0.077285
# SumCyclomatic          WCHU_lcom                              0.080187
# CountStmtExe           ck_oo_fanOut                           0.080891
# SumCyclomaticModified  LDHH_fanIn                             0.082236
# SumCyclomatic          WCHU_dit                               0.084313
# CountStmt              LDHH_cbo                               0.084497
# SumCyclomaticModified  numberOfCriticalBugsFoundUntil:        0.085743
# CountStmt              WCHU_numberOfMethodsInherited          0.087276
# CountStmtExe           WCHU_numberOfAttributesInherited       0.091760
# CountStmt              numberOfHighPriorityBugsFoundUntil:    0.092041
# SumCyclomaticModified  WCHU_fanOut                            0.093832
# CountStmtExe           WCHU_lcom                              0.096531
#                        WCHU_dit                               0.104959
# SumCyclomaticModified  ck_oo_fanOut                           0.108548
# CountStmt              numberOfCriticalBugsFoundUntil:        0.113469
#                        LDHH_fanIn                             0.113890
# SumCyclomaticModified  WCHU_numberOfAttributesInherited       0.115767
# CountStmt              ck_oo_fanOut                           0.117701
#                        WCHU_numberOfMethods                   0.119615
# SumCyclomaticModified  WCHU_lcom                              0.122331
# CountStmt              WCHU_fanOut                            0.129528
# SumCyclomaticModified  WCHU_dit                               0.130996
# CountStmt              WCHU_lcom                              0.131580
#                        WCHU_numberOfAttributesInherited       0.134660
#                        WCHU_dit                               0.143900
# dtype: float64

# %%
strong_pairs = sorted_pairs[(sorted_pairs) > 0.05]

print(strong_pairs)
# Out:
#                        index_name
# AvgLineComment         WCHU_lcom                              0.051302
# CountLine              WCHU_dit                               0.052273
# SumCyclomatic          numberOfCriticalBugsFoundUntil:        0.052740
# CountLine              WCHU_numberOfAttributesInherited       0.052919
# SumCyclomatic          LDHH_fanIn                             0.053633
# CountLine              ck_oo_fanOut                           0.057053
# CountStmtExe           WCHU_numberOfMethods                   0.057566
# AvgLineComment         WCHU_dit                               0.058467
# SumCyclomatic          WCHU_fanOut                            0.059241
# SumCyclomaticModified  WCHU_numberOfMethodsInherited          0.061417
#                        LDHH_cbo                               0.062069
# CountStmtExe           LDHH_fanIn                             0.062345
# SumCyclomaticModified  numberOfHighPriorityBugsFoundUntil:    0.062642
# CountStmtExe           numberOfCriticalBugsFoundUntil:        0.063530
# CountLine              WCHU_lcom                              0.069427
# SumCyclomaticModified  WCHU_numberOfMethods                   0.069628
# CountStmt              ck_oo_dit                              0.073147
# SumCyclomatic          ck_oo_fanOut                           0.073637
#                        WCHU_numberOfAttributesInherited       0.075081
# CountStmtExe           WCHU_fanOut                            0.075198
# CountStmt              WCHU_wmc                               0.077285
# SumCyclomatic          WCHU_lcom                              0.080187
# CountStmtExe           ck_oo_fanOut                           0.080891
# SumCyclomaticModified  LDHH_fanIn                             0.082236
# SumCyclomatic          WCHU_dit                               0.084313
# CountStmt              LDHH_cbo                               0.084497
# SumCyclomaticModified  numberOfCriticalBugsFoundUntil:        0.085743
# CountStmt              WCHU_numberOfMethodsInherited          0.087276
# CountStmtExe           WCHU_numberOfAttributesInherited       0.091760
# CountStmt              numberOfHighPriorityBugsFoundUntil:    0.092041
# SumCyclomaticModified  WCHU_fanOut                            0.093832
# CountStmtExe           WCHU_lcom                              0.096531
#                        WCHU_dit                               0.104959
# SumCyclomaticModified  ck_oo_fanOut                           0.108548
# CountStmt              numberOfCriticalBugsFoundUntil:        0.113469
#                        LDHH_fanIn                             0.113890
# SumCyclomaticModified  WCHU_numberOfAttributesInherited       0.115767
# CountStmt              ck_oo_fanOut                           0.117701
#                        WCHU_numberOfMethods                   0.119615
# SumCyclomaticModified  WCHU_lcom                              0.122331
# CountStmt              WCHU_fanOut                            0.129528
# SumCyclomaticModified  WCHU_dit                               0.130996
# CountStmt              WCHU_lcom                              0.131580
#                        WCHU_numberOfAttributesInherited       0.134660
#                        WCHU_dit                               0.143900
# dtype: float64

# %%
corr_concat = pd.concat([ar5_matrix, jdt_matrix], axis=1, keys=['ar5_matrix', 'jdt_matrix'])
cov = np.cov(corr_concat.T)

print(str(cov))
# Out:
# [[         nan          nan          nan ...          nan          nan
#            nan]
#  [         nan          nan          nan ...          nan          nan
#            nan]
#  [         nan          nan          nan ...          nan          nan
#            nan]
#  ...
#  [         nan          nan          nan ... 489.5860755  187.79626127
#   158.91734071]
#  [         nan          nan          nan ... 187.79626127 398.69556662
#    76.65341327]
#  [         nan          nan          nan ... 158.91734071  76.65341327
#    74.06834005]]

# %%
stds = np.std(corr_concat, axis = 0) #shape = (6,)

stds_matrix = np.array([[stds[i]*stds[j] for j in range(52)] for i in range(52)])

print("standard deviations matrix of shape:",stds_matrix.shape)
# Out:
# standard deviations matrix of shape: (52, 52)

# %%
new_corr = cov/stds_matrix

# %%
pd.options.display.max_seq_items = 2000
print(str(new_corr))
# Out:
# [[       nan        nan        nan ...        nan        nan        nan]
#  [       nan        nan        nan ...        nan        nan        nan]
#  [       nan        nan        nan ...        nan        nan        nan]
#  ...
#  [       nan        nan        nan ... 1.00100402 0.42548821 0.835365  ]
#  [       nan        nan        nan ... 0.42548821 1.00100402 0.44650909]
#  [       nan        nan        nan ... 0.835365   0.44650909 1.00100402]]
